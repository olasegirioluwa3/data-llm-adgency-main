# %% [markdown]
# # Campaign List Segmentation Project: Identifying Target Audiences
#
# This project aims to create three distinct campaign list categories tailored for specific audiences within the MasterList data. By analyzing SIC codes, job titles, and other key identifiers, we will segment the data into targeted lists for:
#
# 1. **Premium Campaign List:**
#
#    - Prioritized based on specific SIC codes (7311, 8721, 8748, 7319, 8742) and primary industries (Advertising, media, marketing, business consulting, tax services, financial services, wealth planning).
#    - Focuses on senior-level positions (excluding "staff") across various job types.
#    - Requires valid business email addresses for direct outreach.
#
# 2. **Conversational AI List:**
#
#    - Compiled based on contact information with valid phone numbers.
#    - Includes job types excluded from the Premium Campaign List (e.g., interns, professors, scientists, engineers).
#
# 3. **Social Media Campaign List:**
#
#    - Leverages job types not targeted in the Premium Campaign List (e.g., social media-related roles).
#    - Ideal for broader reach and engagement through social media platforms.
#
# By segmenting the MasterList data in this way, we can create more focused and effective campaigns for each distinct audience group, maximizing engagement and campaign ROI.
#
# **Key benefits:**
#
# - Increased audience relevance: Tailored messaging for specific needs and interests.
# - Improved campaign performance: Higher engagement and conversion rates.
# - Cost-effective targeting: Optimized resource allocation for each campaign.

# %%
#Import required Packages
import pandas as pd
import numpy as np
from Adfunctions import *
from validate_functions import *
pd.set_option('display.max_rows', 100)

# %%
#Vew list of all functions in the Adfunctions.py file
import inspect
import Adfunctions
# List all functions in the module
functions_list = inspect.getmembers(Adfunctions, inspect.isfunction)
#view all list of functions in the Adfunction package
functions_list
# Out:
# [('count_duplicates', <function Adfunctions.count_duplicates(df)>),
#  ('df_to_excel_openpyxl',
#   <function Adfunctions.df_to_excel_openpyxl(dfs, file_path, sheet_names=None)>),
#  ('drop_rows_with_hyphen',
#   <function Adfunctions.drop_rows_with_hyphen(df, columns)>),
#  ('email_list_creator',
#   <function Adfunctions.email_list_creator(file_path: str, target_industries: list, email_list_name: str)>),
#  ('enrich_email',
#   <function Adfunctions.enrich_email(df, validation_column='BUSINESS_EMAIL_VALIDATION_STATUS', business_email_column='BUSINESS_EMAIL', personal_email_column='PERSONAL_EMAIL', programmatic_email_column='PROGRAMMATIC_BUSINESS_EMAILS')>),
#  ('enrich_phone_numbers', <function Adfunctions.enrich_phone_numbers(df)>),
#  ('filter_and_label_valid_addresses',
#   <function Adfunctions.filter_and_label_valid_addresses(df)>),
#  ('filter_by_seniority',
#   <function Adfunctions.filter_by_seniority(df, exclude_levels=None)>),
#  ('filter_by_sic_codes',
#   <function Adfunctions.filter_by_sic_codes(df, target_sic_codes)>),
#  ('filter_by_target_industries',
#   <function Adfunctions.filter_by_target_industries(df, target_industries)>),
#  ('filter_by_valid_business_email',
#   <function Adfunctions.filter_by_valid_business_email(df, column_name='BUSINESS_EMAIL_VALIDATION_STATUS')>),
#  ('filter_by_valid_business_personal_email',
#   <function Adfunctions.filter_by_valid_business_personal_email(df, validation_column='BUSINESS_EMAIL_VALIDATION_STATUS', business_email_column='BUSINESS_EMAIL', personal_email_column='PERSONAL_EMAIL')>),
#  ('filter_usa_states', <function Adfunctions.filter_usa_states(df)>),
#  ('filter_valid_personal_emails',
#   <function Adfunctions.filter_valid_personal_emails(df)>),
#  ('get_data', <function Adfunctions.get_data(file_path, **kwargs)>),
#  ('list_files_in_folder',
#   <function Adfunctions.list_files_in_folder(folder_path)>),
#  ('liveramp_adlist_creator',
#   <function Adfunctions.liveramp_adlist_creator(file_path: str, target_industries: list, adlist_name: str, **kwargs)>),
#  ('liveramp_formatter', <function Adfunctions.liveramp_formatter(df)>),
#  ('merge_csv_files',
#   <function Adfunctions.merge_csv_files(folder_path, output_file, columns_to_check=None)>),
#  ('save_df_to_csv', <function Adfunctions.save_df_to_csv(df, file_name)>),
#  ('sort_and_filter_jobs',
#   <function Adfunctions.sort_and_filter_jobs(df, keywords_to_exclude)>),
#  ('split_columns_by_separator',
#   <function Adfunctions.split_columns_by_separator(df, columns, separator=',', keep_non_missing_only=True, drop_duplicates=True)>)]

# %%
# Print the data (optional)
df= get_data('./raw_data/Traffic-Convert Agencypartners-Master - Traffic-Convert Agencypartners-MasterList.csv')
df=df[['FIRST_NAME', 'LAST_NAME', 'BUSINESS_EMAIL',
       'PROGRAMMATIC_BUSINESS_EMAILS', 'PERSONAL_EMAIL', 'JOB_TITLE',
       'SENIORITY_LEVEL', 'DEPARTMENT', 'MOBILE_PHONE', 'DIRECT_NUMBER',
       'LINKEDIN_URL', 'PERSONAL_ADDRESS', 'PERSONAL_ADDRESS_2',
       'PERSONAL_CITY', 'PERSONAL_STATE', 'PERSONAL_ZIP', 'PERSONAL_ZIP4',
       'PROFESSIONAL_ADDRESS', 'PROFESSIONAL_ADDRESS_2', 'PROFESSIONAL_CITY',
       'PROFESSIONAL_STATE', 'PROFESSIONAL_ZIP', 'PROFESSIONAL_ZIP4',
       'COMPANY_NAME', 'COMPANY_DOMAIN', 'PRIMARY_INDUSTRY', 'COMPANY_SIC',
       'COMPANY_NAICS', 'COMPANY_ADDRESS', 'COMPANY_ADDRESS_2', 'COMPANY_CITY',
       'COMPANY_STATE', 'COMPANY_ZIP', 'COMPANY_ZIP4', 'COMPANY_LINKEDIN_URL',
       'COMPANY_REVENUE', 'COMPANY_EMPLOYEE_COUNT',
       'BUSINESS_EMAIL_VALIDATION_STATUS', 'BUSINESS_EMAIL_LAST_SEEN',
       'COMPANY_LAST_UPDATED', 'JOB_TITLE_LAST_UPDATED', 'LAST_UPDATED']]

# %%
columns_needed=df.columns.to_list()

# %%
sic_code = ["7311", "8721", "8748", "7319", "8742"]
target_industries = ["Advertising", "Media", "Marketing", "Consulting", "Tax Services", "Financial Services", "Wealth Plan"]

df_filtered = sic_target_industry_filter(df.copy(), sic_code, target_industries)
df_filtered.head()
# Out:
#       FIRST_NAME LAST_NAME              BUSINESS_EMAIL  \
# 81645     Morgen  Williams    mwilliams@yoursummit.com
# 45328   Courtney   Donovan  cdonovan@cerespartners.com
# 69685      Betsy    Graham    betsy@newleaffunding.com
# 37193    Jackson  Dillehay    jdillehay@pciawealth.com
# 46477      Terri     Allen       tallen@pciawealth.com
#
#                             PROGRAMMATIC_BUSINESS_EMAILS  \
# 81645  morgen.williams@yoursummit.com, morgen_william...
# 45328  courtney.donovan@cerespartners.com, courtney_d...
# 69685  betsy.graham@newleaffunding.com, betsy_graham@...
# 37193  jackson.dillehay@pciawealth.com, jackson_dille...
# 46477  terri.allen@pciawealth.com, terri_allen@pciawe...
#
#                                           PERSONAL_EMAIL  \
# 81645                                                  -
# 45328                                                  -
# 69685                     missprissokstatern@outlook.com
# 37193                                                  -
# 46477  crazybabe11014@swbell.net,  dandtlewis@aol.com...
#
#                             JOB_TITLE SENIORITY_LEVEL       DEPARTMENT  \
# 81645  Group Benefits Account Manager         Manager            Sales
# 45328             Executive Assistant           Staff   Administrative
# 69685      Clinical Diabetes Educator           Staff  Health Services
# 37193                          Intern           Staff        Education
# 46477                    Board Member             Cxo        Executive
#
#        MOBILE_PHONE DIRECT_NUMBER  ... COMPANY_ZIP COMPANY_ZIP4  \
# 81645             -  +13178465055  ...       75240         6251
# 45328             -  +15746757700  ...       46617            -
# 69685             -             -  ...       33615            -
# 37193  +16158789131  +12149049911  ...       66211            -
# 46477  +18168387787  +19134916226  ...       66211            -
#
#                                     COMPANY_LINKEDIN_URL  \
# 81645        linkedin.com/company/summit-financial-group
# 45328                linkedin.com/company/ceres-partners
# 69685              linkedin.com/company/new-leaf-funding
# 37193  linkedin.com/company/primecapitalinvestmentadv...
# 46477  linkedin.com/company/primecapitalinvestmentadv...
#
#                   COMPANY_REVENUE COMPANY_EMPLOYEE_COUNT  \
# 81645  100 Million to 250 Million            501 to 1000
# 45328    10 Million to 25 Million              51 to 100
# 69685     5 Million to 10 Million               26 to 50
# 37193   50 Million to 100 Million             251 to 500
# 46477   50 Million to 100 Million             251 to 500
#
#       BUSINESS_EMAIL_VALIDATION_STATUS  BUSINESS_EMAIL_LAST_SEEN  \
# 81645                      Valid (Esp)  2023-07-13T02:34:25.000Z
# 45328                      Valid (Esp)  2023-09-24T18:31:12.000Z
# 69685                                -                         -
# 37193                                -                         -
# 46477                                -                         -
#
#            COMPANY_LAST_UPDATED    JOB_TITLE_LAST_UPDATED  \
# 81645                         -                         -
# 45328  2023-07-01T00:00:00.000Z  2023-07-01T00:00:00.000Z
# 69685                         -                         -
# 37193  2023-09-01T00:00:00.000Z  2023-09-01T00:00:00.000Z
# 46477                         -                         -
#
#                    LAST_UPDATED
# 81645                         -
# 45328  2023-09-24T18:31:12.000Z
# 69685                         -
# 37193                         -
# 46477                         -
#
# [5 rows x 42 columns]

# %%
#Check that atleat one sic_code is in each cell
df_filtered["COMPANY_SIC"].unique().tolist()
# len(df_filtered)
# Out:
# ['0131;  6411;  7389;  8742',
#  '0191;  7323;  8748',
#  '0781;  6799;  8748',
#  '0782;  6799;  8742',
#  '1311;  8742',
#  '1311;  8748',
#  '1389;  8742',
#  '1521;  6211;  8742',
#  '1521;  6531;  8742',
#  '1521;  8721',
#  '1521;  8742',
#  '1521;  8748',
#  '1531;  5946;  8742',
#  '1531;  6289;  8748',
#  '1541;  6282;  8742',
#  '1542;  6099;  8742',
#  '1542;  6159;  8748',
#  '1542;  7372;  8748',
#  '1611;  7622;  8742',
#  '1622;  8742',
#  '8111;  8721',
#  '8111;  8721;  8742',
#  '8111;  8742',
#  '8211;  8713;  8721',
#  '8211;  8713;  8742',
#  '8211;  8721',
#  '8211;  8742',
#  '8221;  8742',
#  '8231;  8742',
#  '8249;  8742',
#  '8299;  8748',
#  '8322;  8742',
#  '8322;  8748',
#  '8611;  8621;  8748',
#  '8611;  8742',
#  '8611;  8742;  8748',
#  '8621;  8721',
#  '8621;  8742',
#  '8641;  8742',
#  '8661;  8742',
#  '8661;  8748',
#  '8699;  8711;  8748',
#  '8699;  8721',
#  '8711;  8732;  8742',
#  '8711;  8742',
#  '8712;  8742',
#  '8713;  8721',
#  '8713;  8748',
#  '8721',
#  '8721;  8742',
#  '8721;  8748',
#  '8732;  8741;  8742',
#  '8732;  8742',
#  '8732;  8748',
#  '8733;  8748',
#  '8734;  8748',
#  '8741;  8742',
#  '8741;  8742;  8748',
#  '8741;  8748',
#  '8742',
#  '8742;  8748',
#  '8748',
#  '2721;  7311;  9531',
#  '3841;  7319;  7322',
#  '4225;  7319;  7322',
#  '5013;  7319;  7322',
#  '5045;  7311;  8743',
#  '5099;  5199;  7221;  7319;  8742;  8811',
#  '5141;  7311;  7389',
#  '5963;  7319;  7322',
#  '6282;  7319;  7389',
#  '6282;  8711;  8742;  9311',
#  '6282;  8721;  8741',
#  '6282;  8742;  8999',
#  '6411;  8748;  8999',
#  '6531;  7319;  7322',
#  '6531;  7319;  7322;  8111',
#  '7231;  7375;  8742;  9111',
#  '7311;  7371;  7372',
#  '7311;  7389',
#  '7311;  7513',
#  '7311;  7991;  8063',
#  '7311;  8211',
#  '7319;  7322',
#  '7319;  7322;  7371',
#  '7319;  7322;  8211;  8711',
#  '7319;  7322;  8641',
#  '7319;  7389',
#  '7319;  8221;  8741',
#  '7389;  8748;  9111',
#  '8322;  8721;  8741',
#  '8699;  8748;  8999',
#  '8721;  8741',
#  '8721;  8743',
#  '8742;  8743',
#  '8742;  8748;  9111',
#  '8742;  8811',
#  '8742;  8999',
#  '8742;  9224',
#  '8742;  9411',
#  '8748;  8999',
#  '8748;  9224',
#  '8748;  9531']

# %%
#filter by seniority   
campaign_data=filter_by_seniority(df_filtered, ["staff"])

campaign_data.SENIORITY_LEVEL.unique()
# Out:
# array(['Cxo', 'Manager', 'Vp', 'Director'], dtype=object)

# %%
#campaign_data["SENIORITY_LEVEL"].value_counts()
campaign_data["BUSINESS_EMAIL_VALIDATION_STATUS"].unique().tolist()
# Out:
# ['-', 'Valid (Esp)', 'Valid (Digital)']

# %% [markdown]
# ## Task1: Creation of Email Maketing list

# %%
def filter_by_valid_business_email(df, column_name="BUSINESS_EMAIL_VALIDATION_STATUS"):
  """
  Filters a dataframe for rows with "Valid" in the BUSINESS_EMAIL_VALIDATION_STATUS column.

  Args:
    df: The dataframe to filter.
    column_name: The name of the column containing validation status.

  Returns:
    A new dataframe containing only rows with validated emails.
  """
  return df[df[column_name].str.contains("Valid", case=False)]

Email_Funnel_Campaign_List=filter_by_valid_business_email(campaign_data, column_name="BUSINESS_EMAIL_VALIDATION_STATUS").reset_index()[columns_needed]

# %%
Email_Funnel_Campaign_List.head()
# Out:
#   FIRST_NAME LAST_NAME                    BUSINESS_EMAIL  \
# 0       Chad     Sluss         csluss@nefassociation.org
# 1      Event      Shop  billy.mcentee@mediafinancial.com
# 2       Tony    Jaynes        tony.jaynes@wegnercpas.com
# 3    Patrick   Estioko        pestioko@frankrimerman.com
# 4    Jeffrey    Filter        jeff.filter@wegnercpas.com
#
#                         PROGRAMMATIC_BUSINESS_EMAILS  \
# 0  chad.sluss@nefassociation.org, chad_sluss@nefa...
# 1  event.shop@mediafinancial.com, event_shop@medi...
# 2  tony.jaynes@wegnercpas.com, tony_jaynes@wegner...
# 3  patrick.estioko@frankrimerman.com, patrick_est...
# 4  jeffrey.filter@wegnercpas.com, jeffrey_filter@...
#
#                                       PERSONAL_EMAIL  \
# 0                                                  -
# 1                                                  -
# 2  tntjaynes@centurytel.net,  jinwood@yahoo.com, ...
# 3                         patrickestioko@hotmail.com
# 4                                                  -
#
#                                 JOB_TITLE SENIORITY_LEVEL  \
# 0                 Chief Executive Officer             Cxo
# 1                                   Owner             Cxo
# 2                        Property Manager         Manager
# 3  Information Technology Network Manager         Manager
# 4                                 Partner             Cxo
#
#                DEPARTMENT  MOBILE_PHONE DIRECT_NUMBER  ... COMPANY_ZIP  \
# 0               Executive  +16162049599  +16164582464  ...       60065
# 1               Executive  +15618763528             -  ...       33401
# 2               Executive             -  +17025971969  ...       53713
# 3  Information Technology             -  +14154392007  ...       94304
# 4               Executive             -  +16085246450  ...       53713
#
#   COMPANY_ZIP4                               COMPANY_LINKEDIN_URL  \
# 0            -  linkedin.com/company/national-equipment-financ...
# 1            -                                                  -
# 2            -                    linkedin.com/company/wegnercpas
# 3            -      linkedin.com/company/frank-rimerman---co--llp
# 4            -                    linkedin.com/company/wegnercpas
#
#               COMPANY_REVENUE COMPANY_EMPLOYEE_COUNT  \
# 0     5 Million to 10 Million               26 to 50
# 1      1 Million to 5 Million               11 to 25
# 2  100 Million to 250 Million            501 to 1000
# 3  250 Million to 500 Million           1001 to 5000
# 4  100 Million to 250 Million            501 to 1000
#
#   BUSINESS_EMAIL_VALIDATION_STATUS  BUSINESS_EMAIL_LAST_SEEN  \
# 0                      Valid (Esp)  2023-08-27T06:58:25.000Z
# 1                      Valid (Esp)  2023-10-01T07:00:00.000Z
# 2                      Valid (Esp)  2023-08-09T03:55:58.000Z
# 3                      Valid (Esp)  2023-03-20T18:57:13.000Z
# 4                      Valid (Esp)  2023-07-26T12:27:08.000Z
#
#        COMPANY_LAST_UPDATED    JOB_TITLE_LAST_UPDATED  \
# 0  2023-06-01T00:00:00.000Z  2023-06-01T00:00:00.000Z
# 1  2023-07-01T00:00:00.000Z  2023-07-01T00:00:00.000Z
# 2  2023-08-01T00:00:00.000Z  2023-08-01T00:00:00.000Z
# 3  2023-08-01T00:00:00.000Z  2023-08-01T00:00:00.000Z
# 4  2023-09-01T00:00:00.000Z  2023-09-01T00:00:00.000Z
#
#                LAST_UPDATED
# 0  2023-08-27T06:58:25.000Z
# 1  2023-10-01T07:00:00.000Z
# 2  2023-08-09T03:55:58.000Z
# 3  2023-08-01T00:00:00.000Z
# 4  2023-09-01T00:00:00.000Z
#
# [5 rows x 42 columns]

# %%
#Check if the result is correct
Email_Funnel_Campaign_List["BUSINESS_EMAIL_VALIDATION_STATUS"].unique().tolist()
# Out:
# ['Valid (Esp)', 'Valid (Digital)']

# %%
Email_Funnel_Campaign_List['JOB_TITLE'].value_counts()
# Out:
# Managing Director                    24
# Owner                                20
# Manager                              17
# President                            15
# Principal                            15
#                                      ..
# Manager, Collections Analytics        1
# Manager Partner Success               1
# Senior Director Of Public Affairs     1
# Board Of Director                     1
# Portfolio Group And Partner           1
# Name: JOB_TITLE, Length: 320, dtype: int64

# %% [markdown]
# ## Task 2:  Filter for Conversation Ai List

# %%
#Write a function to filter phone number

def enrich_phone_numbers(df):
    """
    Enriches phone numbers by replacing "-" with NaN, checking for the column with the lowest number of NaNs,
    and filling missing values based on the corresponding value in the column with more NaNs.

    Args:
        df: The pandas dataframe with phone number columns.

    Returns:
        A new dataframe with an enriched "ENRICHED_PHONE_NUMBER" column, with rows containing NaNs dropped.
    """
    phone_columns = ["MOBILE_PHONE", "DIRECT_NUMBER"]

    # Make a copy of the DataFrame to avoid modifying the original
    df = df.copy()

    # Replace "-" with NaN in the phone number columns
    df[phone_columns] = df[phone_columns].replace('-', np.nan)

    # Count the number of NaNs in each phone column
    na_counts = df[phone_columns].isna().sum()

    # Find the column with the lowest number of NaNs
    lowest_na_column = na_counts.idxmin()

    # Find the column with the highest number of NaNs
    highest_na_column = na_counts.idxmax()

    # Create a new "ENRICHED_PHONE_NUMBER" column and fill with entries from the lowest NA column
    df["ENRICHED_PHONE_NUMBER"] = df[lowest_na_column]

    # Fill missing values with valid entries from the highest NA column (if available)
    mask = df["ENRICHED_PHONE_NUMBER"].isna() & ~df[highest_na_column].isna()
    df.loc[mask, "ENRICHED_PHONE_NUMBER"] = df.loc[mask, highest_na_column]

    # Drop rows with missing values in the "ENRICHED_PHONE_NUMBER" column
    df.dropna(subset=["ENRICHED_PHONE_NUMBER"], inplace=True)

    return df

# Apply the function to the DataFrame and store the result in enriched_df
enriched_df = enrich_phone_numbers(campaign_data)

# %%
# Create a function to sort the data by "JOB_TYPE" and filter out rows where "JOB_TYPE" contains certain keywords such as "intern," "professor," "scientist," "engineer," "mechanical," and "mechanics." 

def sort_and_filter_jobs(df, keywords_to_exclude):
    """
    Sorts the data by JOB_TITLEand filters out rows with specific keywords in JOB_TITLE.

    Args:
        df: The pandas dataframe containing the job data.

    Returns:
        A new dataframe sorted by JOB_TITLE and filtered based on specified keywords.
    """
    
    # Sort the data by JOB_TYPE
    sorted_df = df.sort_values(by="JOB_TITLE")

    # Filter out rows with JOB_TITLE containing the specified keywords
    filtered_df = sorted_df[~sorted_df["JOB_TITLE"].str.lower().str.contains('|'.join(keywords_to_exclude))]

    return filtered_df

# Print the result
keywords_to_exclude = ["intern", "professor", "scientist", "engineer", "mechanical", "mechanics"]
Conversation_AI_List=sort_and_filter_jobs(enriched_df,keywords_to_exclude).reset_index()[["FIRST_NAME", "LAST_NAME","MOBILE_PHONE","DIRECT_NUMBER", "ENRICHED_PHONE_NUMBER"]]
Conversation_AI_List.head(20)
# Out:
#    FIRST_NAME    LAST_NAME  MOBILE_PHONE DIRECT_NUMBER ENRICHED_PHONE_NUMBER
# 0      Callie       Spivey           NaN  +13125684200          +13125684200
# 1      Susana        Perez  +15129644812  +15122570340          +15122570340
# 2      Thomas     Phillips  +18646803812  +18643081218          +18643081218
# 3       Tracy     Daddario           NaN  +17815848019          +17815848019
# 4     Carolyn  Chamberlain  +13865460807  +12399859303          +12399859303
# 5       Shawn    Pellacani  +16504507810  +16504507810          +16504507810
# 6     Jessica     Erickson           NaN  +12122073427          +12122073427
# 7        Anne         Hill           NaN  +13037227776          +13037227776
# 8     Kaleigh         Rowe  +13176946938           NaN          +13176946938
# 9         Bev     Laughlin  +16419190326  +16416933037          +16416933037
# 10       Reen     Williams           NaN  +18043209515          +18043209515
# 11    Jessica         Hull           NaN  +18585235500          +18585235500
# 12      Ellie       Tucker  +13363570797  +15753473400          +15753473400
# 13     Miguel        Ceron  +16193583959  +16122154333          +16122154333
# 14    Quintin         King           NaN  +18008499791          +18008499791
# 15       Adam        Hymer           NaN  +16158723000          +16158723000
# 16     Joshua       Ziegel           NaN  +18589256279          +18589256279
# 17      Diane       Pierce  +17049050216  +19784961177          +19784961177
# 18     Reuben      Harness  +18593240018  +15854211011          +15854211011
# 19      Megan       Jacoby           NaN  +17039930072          +17039930072

# %% [markdown]
# ## Task3: Social Media Campaign List

# %% [markdown]
#  * Create a function that takes a DataFrame and returns a new DataFrame containing only rows with valid 'PERSONAL_EMAIL' addresses for all job types:

# %%
def filter_valid_personal_emails(df):
    """
    Filters a DataFrame to include only rows with valid 'PERSONAL_EMAIL' addresses for all job types.

    Args:
        df: The pandas DataFrame containing 'JOB_TYPE' and 'PERSONAL_EMAIL' columns.

    Returns:
        A new DataFrame with rows containing valid 'PERSONAL_EMAIL' addresses for all job types.
    """
    # Filter rows with valid 'PERSONAL_EMAIL'
    valid_email_df = df[df['PERSONAL_EMAIL'].str.contains('@', na=False)]

    return valid_email_df

#Apply the function on df_filtered 
Social_Media_Mampaign_list=filter_valid_personal_emails(df_filtered).reset_index()[columns_needed]

# %%
Social_Media_Mampaign_list["SENIORITY_LEVEL"].value_counts()
# Out:
# Staff       859
# Manager     342
# Cxo         321
# Vp          109
# Director    108
# -            41
# Name: SENIORITY_LEVEL, dtype: int64

# %% [markdown]
# ## Combine all the Campaign List into a single excel workbook

# %%
#Combine all files into single workbook

def df_to_excel_openpyxl(dfs, file_path, sheet_names=None):
    """
    Combines multiple pandas dataframes into a single Excel file with different sheets, 
    adding the number of rows to each sheet name.

    Args:
        dfs: A list of pandas dataframes to write.
        file_path: The path to save the file.
        sheet_names: A list of names for the sheets (optional, defaults to DataFrame titles).

    Returns:
        None
    """
    wb = Workbook()

    for df, name in zip(dfs, sheet_names):
        sheet_name = f"{name}_{len(df)}"
        ws = wb.create_sheet(sheet_name)
        ws.append(df.columns.tolist())
        for row in df.values:
            ws.append(row.tolist())

    wb.save(file_path)
# Apply the function
# dfs=[Email_Funnel_Campaign_List, Conversation_AI_List, Social_Media_Mampaign_list]
# sheet_names=["Email_Funnel_Campaign_List", "Conversation_AI_List", "Social_Media_Mampaign_list"]
# df_to_excel_openpyxl(dfs, "Traffic-Convert_Campaign_data.xlsx", sheet_names)

# %% [markdown]
# # Second campagn list Task

# %% [markdown]
# 1. states must be US states len(2)
# 2. take address from personal, professional, and business Address, must not be P.O.Box
#
# second task
# 1. industry list=[advert, media, intertainment, PR, Events, Printing, marketing,publishing, broadcast]
# 2. sic code 7311
# 3. address

# %%
#read data using get_data function
first_list=get_data("./raw_data/Adgency-7311_SecondPriority.csv")
target_industries=['Advertising Services', 'Marketing','Book And Periodical Publishing', 'Entertainment Providers', 'Events Services','Broadcast Media Production And Distribution','Public Relations And Communications Services', 'Online Audio And Video Media', 'Printing Services','Newspaper Publishing', 'Newspapers']

# %%
#Get saze of data
first_list.shape
# Out:
# (100000, 42)

# %%
#get columns names
first_list.columns
# Out:
# Index(['FIRST_NAME', 'LAST_NAME', 'BUSINESS_EMAIL',
#        'PROGRAMMATIC_BUSINESS_EMAILS', 'PERSONAL_EMAIL', 'JOB_TITLE',
#        'SENIORITY_LEVEL', 'DEPARTMENT', 'MOBILE_PHONE', 'DIRECT_NUMBER',
#        'LINKEDIN_URL', 'PERSONAL_ADDRESS', 'PERSONAL_ADDRESS_2',
#        'PERSONAL_CITY', 'PERSONAL_STATE', 'PERSONAL_ZIP', 'PERSONAL_ZIP4',
#        'PROFESSIONAL_ADDRESS', 'PROFESSIONAL_ADDRESS_2', 'PROFESSIONAL_CITY',
#        'PROFESSIONAL_STATE', 'PROFESSIONAL_ZIP', 'PROFESSIONAL_ZIP4',
#        'COMPANY_NAME', 'COMPANY_DOMAIN', 'PRIMARY_INDUSTRY', 'COMPANY_SIC',
#        'COMPANY_NAICS', 'COMPANY_ADDRESS', 'COMPANY_ADDRESS_2', 'COMPANY_CITY',
#        'COMPANY_STATE', 'COMPANY_ZIP', 'COMPANY_ZIP4', 'COMPANY_LINKEDIN_URL',
#        'COMPANY_REVENUE', 'COMPANY_EMPLOYEE_COUNT',
#        'BUSINESS_EMAIL_VALIDATION_STATUS', 'BUSINESS_EMAIL_LAST_SEEN',
#        'COMPANY_LAST_UPDATED', 'JOB_TITLE_LAST_UPDATED', 'LAST_UPDATED'],
#       dtype='object')

# %%
#filter for USA states only
state_df=filter_usa_states(first_list)

# %%
state_df.shape
# Out:
# (71239, 42)

# %%
#filter for valid address
valid_address_df=filter_and_label_valid_addresses(state_df.copy())

# %%
valid_address_df.shape
# Out:
# (69176, 44)

# %%
#save to file
save_df_to_csv(valid_address_df,'first_priority_valid_address_list')
# Out:
# DataFrame successfully saved to Output_list_DataBase\first_priority_valid_address_list.csv

# %%
valid_numbers=enrich_phone_numbers(valid_address_df.copy())

# %%
#check the number 
valid_numbers.shape
# Out:
# (48567, 45)

# %%
#filter for valid business number enriched with personal number for non-validated business emails
valid_number_email_df=filter_by_valid_business_personal_email(valid_numbers,
                                                           validation_column = "BUSINESS_EMAIL_VALIDATION_STATUS",
                                                           business_email_column= "BUSINESS_EMAIL",
                                                           personal_email_column = "PERSONAL_EMAIL")

# %%
valid_number_email_df.columns
# Out:
# Index(['FIRST_NAME', 'LAST_NAME', 'BUSINESS_EMAIL',
#        'PROGRAMMATIC_BUSINESS_EMAILS', 'PERSONAL_EMAIL', 'JOB_TITLE',
#        'SENIORITY_LEVEL', 'DEPARTMENT', 'MOBILE_PHONE', 'DIRECT_NUMBER',
#        'LINKEDIN_URL', 'PERSONAL_ADDRESS', 'PERSONAL_ADDRESS_2',
#        'PERSONAL_CITY', 'PERSONAL_STATE', 'PERSONAL_ZIP', 'PERSONAL_ZIP4',
#        'PROFESSIONAL_ADDRESS', 'PROFESSIONAL_ADDRESS_2', 'PROFESSIONAL_CITY',
#        'PROFESSIONAL_STATE', 'PROFESSIONAL_ZIP', 'PROFESSIONAL_ZIP4',
#        'COMPANY_NAME', 'COMPANY_DOMAIN', 'PRIMARY_INDUSTRY', 'COMPANY_SIC',
#        'COMPANY_NAICS', 'COMPANY_ADDRESS', 'COMPANY_ADDRESS_2', 'COMPANY_CITY',
#        'COMPANY_STATE', 'COMPANY_ZIP', 'COMPANY_ZIP4', 'COMPANY_LINKEDIN_URL',
#        'COMPANY_REVENUE', 'COMPANY_EMPLOYEE_COUNT',
#        'BUSINESS_EMAIL_VALIDATION_STATUS', 'BUSINESS_EMAIL_LAST_SEEN',
#        'COMPANY_LAST_UPDATED', 'JOB_TITLE_LAST_UPDATED', 'LAST_UPDATED',
#        'VALID_ADDRESS', 'ADDRESS_USED', 'ENRICHED_PHONE_NUMBER',
#        'Valid_Business_Email'],
#       dtype='object')

# %%
df_progra_emails=split_columns_by_separator(valid_number_email_df, 'PROGRAMMATIC_BUSINESS_EMAILS', separator=',',keep_non_missing_only=True,drop_duplicates=True)
df_progra_emails.columns
# Out:
# Index(['FIRST_NAME', 'LAST_NAME', 'BUSINESS_EMAIL',
#        'PROGRAMMATIC_BUSINESS_EMAILS', 'PERSONAL_EMAIL', 'JOB_TITLE',
#        'SENIORITY_LEVEL', 'DEPARTMENT', 'MOBILE_PHONE', 'DIRECT_NUMBER',
#        'LINKEDIN_URL', 'PERSONAL_ADDRESS', 'PERSONAL_ADDRESS_2',
#        'PERSONAL_CITY', 'PERSONAL_STATE', 'PERSONAL_ZIP', 'PERSONAL_ZIP4',
#        'PROFESSIONAL_ADDRESS', 'PROFESSIONAL_ADDRESS_2', 'PROFESSIONAL_CITY',
#        'PROFESSIONAL_STATE', 'PROFESSIONAL_ZIP', 'PROFESSIONAL_ZIP4',
#        'COMPANY_NAME', 'COMPANY_DOMAIN', 'PRIMARY_INDUSTRY', 'COMPANY_SIC',
#        'COMPANY_NAICS', 'COMPANY_ADDRESS', 'COMPANY_ADDRESS_2', 'COMPANY_CITY',
#        'COMPANY_STATE', 'COMPANY_ZIP', 'COMPANY_ZIP4', 'COMPANY_LINKEDIN_URL',
#        'COMPANY_REVENUE', 'COMPANY_EMPLOYEE_COUNT',
#        'BUSINESS_EMAIL_VALIDATION_STATUS', 'BUSINESS_EMAIL_LAST_SEEN',
#        'COMPANY_LAST_UPDATED', 'JOB_TITLE_LAST_UPDATED', 'LAST_UPDATED',
#        'VALID_ADDRESS', 'ADDRESS_USED', 'ENRICHED_PHONE_NUMBER',
#        'Valid_Business_Email', 'PROGRAMMATIC_BUSINESS_EMAILS_1',
#        'PROGRAMMATIC_BUSINESS_EMAILS_2', 'PROGRAMMATIC_BUSINESS_EMAILS_3',
#        'PROGRAMMATIC_BUSINESS_EMAILS_4', 'PROGRAMMATIC_BUSINESS_EMAILS_5',
#        'PROGRAMMATIC_BUSINESS_EMAILS_6', 'PROGRAMMATIC_BUSINESS_EMAILS_7',
#        'PROGRAMMATIC_BUSINESS_EMAILS_8', 'PROGRAMMATIC_BUSINESS_EMAILS_9',
#        'PROGRAMMATIC_BUSINESS_EMAILS_10', 'PROGRAMMATIC_BUSINESS_EMAILS_11',
#        'PROGRAMMATIC_BUSINESS_EMAILS_12', 'PROGRAMMATIC_BUSINESS_EMAILS_13',
#        'PROGRAMMATIC_BUSINESS_EMAILS_14', 'PROGRAMMATIC_BUSINESS_EMAILS_15',
#        'PROGRAMMATIC_BUSINESS_EMAILS_16', 'PROGRAMMATIC_BUSINESS_EMAILS_17'],
#       dtype='object')

# %%
# Example usage:
# Assume 'data' is your original DataFrame loaded with necessary columns
# selected_columns = { ... } # Define your column mapping as provided earlier
formatted_df = liveramp_formatter(df_progra_emails)
formatted_df
# Out:
#        Client Customer ID First Name Last Name     Street Address 1  \
# 0                    7253      Nhora    Murphy   3410 Galt Ocean Dr
# 5                    7706       Mary  Mccauley  7202 Whitmore Lk Rd
# 7                    2969      Junia     Bauer  23 N Cir Dr Apt W11
# 13                   1584      Keith       Kan   8521 Pepperdine Dr
# 16                   9068     Angela    Strain         4320 Hwy 365
# ...                   ...        ...       ...                  ...
# 99990                9126     Bonnie   Overton   11000 Regency Pkwy
# 99991                9059      Emily      Hean        555 Market St
# 99993                9909     Monica    Leedom      8671 Cord St Ne
# 99995                5143       Kate    Brochu        345 Hudson St
# 99997                9293   Caroline     Kenne      4299 Webster Dr
#
#       Street Address 2              City State Zip Code Zip Code Plus 4  \
# 0                    -   Fort Lauderdale    FL    33308               -
# 5                  NaN          Brighton    MI        -               -
# 7                    -  Colorado Springs    CO    80909            6368
# 13                   -            Vienna    VA    22180            7047
# 16                   -       Port Arthur    TX    77642            7516
# ...                ...               ...   ...      ...             ...
# 99990              NaN           Raleigh    NC        -               -
# 99991              NaN                 -    CA        -               -
# 99993     3250 Rice St      Circle Pines    MN    55014               -
# 99995                -                 -    NY        -               -
# 99997                -              York    PA    17402            3332
#
#                                Email1                              Email2  \
# 0                 nmurphy@tmncorp.com            nhora.murphy@tmncorp.com
# 5                                   -    mary.mccauley@brightonagency.com
# 7               craig.buell@yahoo.com         junia.bauer@hobbsherder.com
# 13                asideat52@yahoo.com                    keith.kan@wk.com
# 16       star_to_star2001@yahoo.co.in      angela.strain@colliersimon.com
# ...                               ...                                 ...
# 99990           saphire0777@gmail.com       bonnie.overton@evokegroup.com
# 99991             emily.hean@rapp.com                 emily.hean@rapp.com
# 99993    mleedom@mngamingservices.com  monica.leedom@mngamingservices.com
# 99995                               -      kate.brochu@everydayhealth.com
# 99997      alexandriagrey@comcast.net      caroline.kenne@karmaagency.com
#
#                                     Email3  PhoneNumber1  PhoneNumber2
# 0                 nhora_murphy@tmncorp.com  +13014680956           NaN
# 5         mary_mccauley@brightonagency.com  +13139782253           NaN
# 7              junia_bauer@hobbsherder.com  +12033562496  +17209994687
# 13                        keith_kan@wk.com  +17035735754           NaN
# 16          angela_strain@colliersimon.com  +14097242203  +19012735641
# ...                                    ...           ...           ...
# 99990        bonnie_overton@evokegroup.com  +19194630330           NaN
# 99991                  emily_hean@rapp.com  +15033481744           NaN
# 99993   monica_leedom@mngamingservices.com  +16516384638  +16513076267
# 99995       kate_brochu@everydayhealth.com  +15182659117           NaN
# 99997       caroline_kenne@karmaagency.com  +16172049500  +17175720473
#
# [48567 rows x 14 columns]

# %%
count_duplicates(formatted_df)
formatted_df.shape
# Out:
# (48567, 14)

# %%
#Save to file
save_df_to_csv(formatted_df,"email_number_liveramp_list1")
# Out:
# DataFrame successfully saved to Output_list_DataBase\email_number_liveramp_list1.csv

# %% [markdown]
# # Second Priority List

# %%
target_industries=['Advertising Services', 'Animation And Post-Production','Writing And Editing', 'Fundraising','Spectator Sports','Movies, Videos, And Sound','Marketing','Book And Periodical Publishing', 'Entertainment Providers', 'Events Services','Broadcast Media Production And Distribution','Public Relations And Communications Services', 'Online Audio And Video Media', 'Printing Services','Newspaper Publishing', 'Newspapers', 'Sports', 'Motion Pictures And Film']
sic_codes = ['7311']

# %%
#Read in Data
df_second=get_data('./raw_data/Adgency-7311_SecondPriority.csv')

#display the dimension of the data
dim=df_second.shape
print(f"The data has {dim[0]} rows and {dim[1]} columns")
# Out:
# The data has 100000 rows and 42 columns

# %%
df_second.copy().COMPANY_SIC
# Out:
# 0                      7311;  8721
# 1                             7311
# 2                             7311
# 3               5092;  6531;  7311
# 4                      5963;  7311
#                    ...
# 99995           7311;  8099;  8733
# 99996    2754;  2782;  7311;  7319
# 99997                  7311;  8743
# 99998           6411;  6531;  7311
# 99999                  5113;  7311
# Name: COMPANY_SIC, Length: 100000, dtype: object

# %%
#check the effect of filter by sic code
filter_by_sic_codes(df_second.copy(),sic_codes).shape
# Out:
# (100000, 42)

# %%
#filter by industry
df_industry=filter_by_target_industries(df_second, target_industries)

# %%
#dimension
df_industry.shape
# Out:
# (64617, 42)

# %%
#validate
valid=validate_filter_by_target_industries_output(df_industry, target_industries)
valid
# Out:
# True

# %%
df_industry.PRIMARY_INDUSTRY.unique().tolist()
# Out:
# ['Advertising Services',
#  'Book And Periodical Publishing',
#  'Entertainment Providers',
#  'Events Services',
#  'Broadcast Media Production And Distribution',
#  'Movies, Videos, And Sound',
#  'Spectator Sports',
#  'Public Relations And Communications Services',
#  'Online Audio And Video Media',
#  'Printing Services',
#  'Fundraising',
#  'Newspaper Publishing',
#  '6411;  7311;  7331',
#  '3493;  7311',
#  '1799;  5048;  7311',
#  '7311;  7929;  8743',
#  '5051;  7311;  8742',
#  '5719;  7311',
#  '7311;  8713',
#  '5199;  5411;  7311',
#  '3663;  7311',
#  '7311;  7319;  8082',
#  '7311;  7319;  9641',
#  '2515;  5065;  7311',
#  '2741;  5141;  7311',
#  '7311;  8621;  8743',
#  '4899;  7311;  8111',
#  '5021;  5199;  7311',
#  '2542;  7311',
#  '5531;  7311;  8399',
#  '4731;  7311;  8742',
#  '2752;  7219;  7311',
#  '5199;  7311;  8742',
#  '5112;  7311;  7331',
#  '4813;  7311;  7999',
#  '7311;  7313;  7941',
#  '2044;  7311;  8743',
#  '5632;  7311;  7331',
#  '5049;  7311;  7389',
#  '4212;  5199;  7311',
#  '7311;  7389;  8211',
#  '5199;  7221;  7311',
#  ...]

# %%
# def filter_by_valid_business_personal_email(df, validation_column="BUSINESS_EMAIL_VALIDATION_STATUS", business_email_column="BUSINESS_EMAIL", personal_email_column="PERSONAL_EMAIL"):
#     """
#     [Function Description]
#     """
#     df_processed = df.copy()

#     # Determine whether each business email is valid
#     is_valid = df_processed[validation_column].str.contains("Valid", case=False, na=False)

#     def get_valid_email(business_email, personal_emails, is_valid_email):
#         if is_valid_email:
#             return business_email
#         else:
#             personal_emails_list = personal_emails.split(',') if isinstance(personal_emails, str) else [personal_emails]
#             # Select an alternate personal email if available, or the first one in the list
#             return personal_emails_list[1] if len(personal_emails_list) > 1 else personal_emails_list[0]

#     df_processed['Valid_Business_Email'] = df_processed.apply(lambda row: get_valid_email(row[business_email_column], row[personal_email_column], is_valid[row.name]), axis=1)

#     return df_processed

# %%
#Filter by Valid Busines email
Email_7311_list=filter_by_valid_business_personal_email(
    df=df_industry,
    validation_column="BUSINESS_EMAIL_VALIDATION_STATUS",
    business_email_column="BUSINESS_EMAIL",
    personal_email_column="PERSONAL_EMAIL"
)

# %%
# check the size of your data
Email_7311_list.shape
# Out:
# (64617, 43)

# %%
#drop empty rows in vaid business email
email_list_7311=drop_rows_with_hyphen(Email_7311_list, "Valid_Business_Email")

# %%
#enrich email values
list_emial_phone=enrich_phone_numbers(email_list_7311)

# %%
list_emial_phone[['FIRST_NAME','LAST_NAME','Valid_Business_Email',"ENRICHED_PHONE_NUMBER"]]
# Out:
#       FIRST_NAME LAST_NAME            Valid_Business_Email  \
# 0          Nhora    Murphy             nmurphy@tmncorp.com
# 7          Junia     Bauer           craig.buell@yahoo.com
# 13         Keith       Kan             asideat52@yahoo.com
# 16        Angela    Strain    star_to_star2001@yahoo.co.in
# 21         Annis   Kishner      annisekishner447@yahoo.com
# ...          ...       ...                             ...
# 99989      Rishi     Doshi         rdoshi@horizonmedia.com
# 99990     Bonnie   Overton           saphire0777@gmail.com
# 99991      Emily      Hean             emily.hean@rapp.com
# 99994       Greg    George            snowgrains@yahoo.com
# 99997   Caroline     Kenne      alexandriagrey@comcast.net
#
#       ENRICHED_PHONE_NUMBER
# 0              +13014680956
# 7              +12033562496
# 13             +17035735754
# 16             +14097242203
# 21             +14048127000
# ...                     ...
# 99989          +12122204916
# 99990          +19194630330
# 99991          +15033481744
# 99994          +13126162339
# 99997          +16172049500
#
# [33874 rows x 4 columns]

# %%
valid_email_columns=['First_Name','Last_Name','Valid_Business_Email',"Phone_number"]
email=list_emial_phone[valid_email_columns]

# %%
email.shape
# Out:
# (33874, 4)

# %%
save_df_to_csv(email, "email_phone_7311_list2")
# Out:
# DataFrame successfully saved to Output_list_DataBase\email_phone_7311_list2.csv

# %%
merge_csv_files("./merger_input_data","./output_list_database/combined_emai_list.csv",['Valid_Business_Email'])
# Out:
# Merged data saved to './output_list_database/combined_emai_list.csv' and duplicates removed.

# %%
my_data=get_data('output_list_database\combined_emai_list.csv')

# %%
my_data.duplicated().value_counts()
# Out:
# False    49194
# dtype: int64

# %%
primary_industries=['Advertising Services', 'Marketing','Book And Periodical Publishing', 'Entertainment Providers', 'Events Services','Broadcast Media Production And Distribution','Public Relations And Communications Services', 'Online Audio And Video Media', 'Printing Services','Newspaper Publishing', 'Newspapers']
liveramp_adlist_creator(file_path='./raw_data/Adpromoter_FirstPriority.csv', target_industries=primary_industries, adlist_name='second_priority_liveramp_list')

# %% [markdown]
# ## Events Promoters data Wrangling

# %%
#read in Data
event_df=get_data("./raw_data/Event-Promoter.csv")

# %%
#Get the list of primary industries
event_df["PRIMARY_INDUSTRY"].unique().tolist()
# Out:
# ['Events Services', 'Advertising Services']

# %%
'''
save primary industry in a variable and Call the Lieramp_adlist function to create the list \
    for event promoter conforming with Liveramp standard
 '''   
primary_indust=['Events Services', 'Advertising Services']
liveramp_adlist_creator(file_path="./raw_data/Event-Promoter.csv", target_industries=primary_indust, adlist_name='events_liveramp__list')
# Out:
# DataFrame successfully saved to Output_list_DataBase\events_liveramp__list.csv

# %%
event_list_df=get_data("./output_list_database/events_liveramp__list.csv")

# %%
event_list_df.head()
# Out:
#    Client Customer ID First Name  Last Name     Street Address 1  \
# 0                4264     Marcia       Lane        401 E 54th St
# 1                2624    Leticia  Del Moral      8911 Laguna Fls
# 2                1464       Mark    Sherwin  185 Bald Head Is Dr
# 3                8885      Karen   Pattison    7500 E Juniper Dr
# 4                8221     Martha      Kraft   1833 Timber Rdg Rd
#
#          Street Address 2         City State Zip Code Zip Code Plus 4  \
# 0                       -  Kansas City    MO    64110            2407
# 1                       -  San Antonio    TX    78251            4958
# 2  125 Edinburgh South Dr       Garner    NC    27529            6146
# 3                       -       Tucson    AZ    85730               -
# 4                       -      Lincoln    NE    68522               -
#
#                            Email1                               Email2  \
# 0  marcia@inspiredoccasionskc.com  marcia.lane@inspiredoccasionskc.com
# 1         lettydelmoral@yahoo.com       leticia.del moral@getnside.com
# 2            mark@leadsnearby.com         mark.sherwin@leadsnearby.com
# 3           skivallykaren@aim.com           karen.pattison@jwevents.ca
# 4          molberding@hotmail.com       martha.kraft@kraftworksnyc.com
#
#                                  Email3  PhoneNumber1  PhoneNumber2
# 0   marcia_lane@inspiredoccasionskc.com   18164448224  1.816511e+10
# 1        leticia_del moral@getnside.com   12105212807  1.210414e+10
# 2          mark_sherwin@leadsnearby.com   14805355024  1.919831e+10
# 3            karen_pattison@jwevents.ca   15203259110  1.520808e+10
# 4        martha_kraft@kraftworksnyc.com   14024234427  1.913927e+10

# %%
merge_csv_files("./merger_input_data","./output_list_database/events_combined__liveramp_list.csv",["Email1","PhoneNumber1"])
# Out:
# Merged data saved to './output_list_database/events_combined__liveramp_list.csv' and duplicates removed.

# %%
size=get_data("./output_list_database/events_combined__liveramp_list.csv").shape

# %%
#Display the size of the data
f"Total number of rows={size[0]}"
# Out:
# 'Total number of rows=101984'

# %% [markdown]
# ## Email list

# %%
# priority ads promoter industry
primary_industries=['Advertising Services', 'Marketing','Book And Periodical Publishing', 'Entertainment Providers', 'Events Services','Broadcast Media Production And Distribution','Public Relations And Communications Services', 'Online Audio And Video Media', 'Printing Services','Newspaper Publishing', 'Newspapers']
#event promoter industries
primary_indust=['Events Services', 'Advertising Services']

# %%
#email list first priority list
email_list_creator("./raw_data/Adpromoter_FirstPriority.csv",primary_industries, "first_ad_promoter_email_list")
# #second priority list
email_list_creator("./raw_data/Adpromoter_FirstPriority.csv",primary_industries, "second_ad_promoter_email_list")
#events promoter email list
email_list_creator("./raw_data/Event-Promoter.csv",primary_indust, "event_promoter_email_list")
# Out:
# DataFrame successfully saved to Output_list_DataBase\first_ad_promoter_email_list.csv
# DataFrame successfully saved to Output_list_DataBase\second_ad_promoter_email_list.csv
# DataFrame successfully saved to Output_list_DataBase\event_promoter_email_list.csv

# %%
merge_csv_files("./merger_input_data/number_data/","./output_list_database/final_combined_email_list.csv", "Email")
# Out:
# Merged data saved to './output_list_database/final_combined_email_list2.csv' and duplicates removed.

# %%
email=get_data("./output_list_database/final_combined_email_list.csv")

# %%
f"Total number of emails={email.shape[0]}"
# Out:
# 'Total number of emails=101173'

# %%
email.head(
    
)
# Out:
#   First Name  Last Name                    Email
# 0     Marcia       Lane  marcialane401@gmail.com
# 1    Leticia  Del Moral  lettydelmoral@yahoo.com
# 2       Mark    Sherwin      sherwin16@gmail.com
# 3      Karen   Pattison   skivalleykaren@aol.com
# 4     Martha      Kraft   molberding@hotmail.com

# %%
#check for duplicates
count_duplicates(email)
# Out:
# 'No duplicates found.'

# %%
liveramp_df=get_data("./output_list_database/events_combined__liveramp_list.csv")

# %%
f"Total number of rows={liveramp_df.shape[0]}"
# Out:
# 'Total number of rows=101984'

# %%
liveramp_df.head(10)
# Out:
#    Client Customer ID First Name  Last Name               Street Address 1  \
# 0                7253      Nhora     Murphy             3410 Galt Ocean Dr
# 1                7706       Mary   Mccauley            7202 Whitmore Lk Rd
# 2                2969      Junia      Bauer            23 N Cir Dr Apt W11
# 3                1584      Keith        Kan             8521 Pepperdine Dr
# 4                9068     Angela     Strain                   4320 Hwy 365
# 5                7317       Eric  Deichmann                      26 Mdw Rd
# 6                9169    Michael     Haslam                 980 Hammond Dr
# 7                9335      Annis    Kishner                55 Cambridge St
# 8                8789      Bruce   Bildsten               147 Prospect Ave
# 9                9383      Angel   Swindell  8611 Concord Mls Blvd Ste 201
#
#            Street Address 2              City State Zip Code Zip Code Plus 4  \
# 0                         -   Fort Lauderdale    FL    33308               -
# 1                       NaN          Brighton    MI        -               -
# 2                         -  Colorado Springs    CO    80909            6368
# 3                         -            Vienna    VA    22180            7047
# 4                         -       Port Arthur    TX    77642            7516
# 5               909 3rd Ave         Riverside    CT        -            2328
# 6                       NaN           Atlanta    GA        -               -
# 7                       NaN       Los Angeles    CA        -               -
# 8                         -       Minneapolis    MN    55419            1303
# 9  1350 Pennsylvania Ave Nw           Concord    NC    28027            5400
#
#                            Email1                                   Email2  \
# 0             nmurphy@tmncorp.com                 nhora.murphy@tmncorp.com
# 1                               -         mary.mccauley@brightonagency.com
# 2           craig.buell@yahoo.com              junia.bauer@hobbsherder.com
# 3             asideat52@yahoo.com                         keith.kan@wk.com
# 4    star_to_star2001@yahoo.co.in           angela.strain@colliersimon.com
# 5    erdeichmann@alixpartners.com          eric.deichmann@alixpartners.com
# 6         mhaslam@redventures.com           michael.haslam@redventures.com
# 7      annisekishner447@yahoo.com  annis.kishner@alliedglobalmarketing.com
# 8          willbildsten@gmail.com                bruce.bildsten@fallon.com
# 9         zenith.laston@yahoo.com                   angel.swindell@ccl.org
#
#                                      Email3  PhoneNumber1  PhoneNumber2
# 0                  nhora_murphy@tmncorp.com   13014680956           NaN
# 1          mary_mccauley@brightonagency.com   13139782253           NaN
# 2               junia_bauer@hobbsherder.com   12033562496  1.720999e+10
# 3                          keith_kan@wk.com   17035735754           NaN
# 4            angela_strain@colliersimon.com   14097242203  1.901274e+10
# 5           eric_deichmann@alixpartners.com   12126828808  1.860861e+10
# 6            michael_haslam@redventures.com   13019269734  1.909384e+10
# 7   annis_kishner@alliedglobalmarketing.com   14048127000  1.310780e+10
# 8                 bruce_bildsten@fallon.com   16128220422  1.612877e+10
# 9                    angel_swindell@ccl.org   15137291115  1.704702e+10

# %%
get_data("./raw_data\Adgency-7311_SecondPriority.csv").columns
# Out:
# Index(['FIRST_NAME', 'LAST_NAME', 'BUSINESS_EMAIL',
#        'PROGRAMMATIC_BUSINESS_EMAILS', 'PERSONAL_EMAIL', 'JOB_TITLE',
#        'SENIORITY_LEVEL', 'DEPARTMENT', 'MOBILE_PHONE', 'DIRECT_NUMBER',
#        'LINKEDIN_URL', 'PERSONAL_ADDRESS', 'PERSONAL_ADDRESS_2',
#        'PERSONAL_CITY', 'PERSONAL_STATE', 'PERSONAL_ZIP', 'PERSONAL_ZIP4',
#        'PROFESSIONAL_ADDRESS', 'PROFESSIONAL_ADDRESS_2', 'PROFESSIONAL_CITY',
#        'PROFESSIONAL_STATE', 'PROFESSIONAL_ZIP', 'PROFESSIONAL_ZIP4',
#        'COMPANY_NAME', 'COMPANY_DOMAIN', 'PRIMARY_INDUSTRY', 'COMPANY_SIC',
#        'COMPANY_NAICS', 'COMPANY_ADDRESS', 'COMPANY_ADDRESS_2', 'COMPANY_CITY',
#        'COMPANY_STATE', 'COMPANY_ZIP', 'COMPANY_ZIP4', 'COMPANY_LINKEDIN_URL',
#        'COMPANY_REVENUE', 'COMPANY_EMPLOYEE_COUNT',
#        'BUSINESS_EMAIL_VALIDATION_STATUS', 'BUSINESS_EMAIL_LAST_SEEN',
#        'COMPANY_LAST_UPDATED', 'JOB_TITLE_LAST_UPDATED', 'LAST_UPDATED'],
#       dtype='object')

# %%
import csv
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get(url)
 
print(response)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Sales Navigator</title>
# <meta content="" name="description"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <style>
#       /* stylelint-disable */
#       .initial-load-animation {
#         padding-top: 96px;
#         width: 200px;
#         margin: 0 auto;
#         transform: scale(1);
#         transition: transform .5s ease;
#       }
#       .salesnav-image {
#         background-image: url('https://static.licdn.com/aero-v1/sc/h/v4ody32j7r2zqlkj9lxg96x3');
#         height: 55px;
#         width: 55px;
#         margin: 0 auto;
#         margin-bottom: 32px;
#         transform: translate(0, 0);
#         opacity: 1;
#         transition: all .5s ease-out;
#       }
#       .loading-bar {
#         width: 130px;
#         height: 2px;
#         margin: 0 auto;
#         border-radius: 2px;
#         background-color: #CFCFCF;
#         position: relative;
#         overflow: hidden;
#         z-index: 1;
#         transform: rotateY(0);
#         transition: transform .3s ease-in;
#       }
#       .blue-bar {
#         height: 100%;
#         width: 68px;
#         position: absolute;
#         transform: translate(-34px, 0);
#         background-color: #0073B1;
#         border-radius: 2px;
#         animation: initial-loading 1.5s infinite ease;
#       }
#       @keyframes initial-loading {
#         0% {
#           transform: translate(-34px, 0);
#         }
#         50% {
#           transform: translate(96px, 0);
#         }
#         100% {
#           transform: translate(-34px, 0);
#         }
#       }
#       .boot-complete .initial-loading-state,
#       .hide-loading.initial-loading-state {
#         display: none;
#       }
#       /* stylelint-enable */
#     </style>
# <meta content="%7B%22alternativeId%22%3A%22originalId%22%2C%22modulePrefix%22%3A%22lighthouse-web%22%2C%22deviceFormFactor%22%3A%22DESKTOP%22%2C%22environment%22%3A%22production%22%2C%22rootURL%22%3A%22%2F%22%2C%22locationType%22%3A%22auto-hash-params%22%2C%22historySupportMiddleware%22%3Atrue%2C%22autoHashConfig%22%3A%7B%22maxQueryParamBytes%22%3A4096%7D%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%2C%22EXTEND_PROTOTYPES%22%3A%7B%22Date%22%3Afalse%7D%2C%22_APPLICATION_TEMPLATE_WRAPPER%22%3Afalse%2C%22_DEFAULT_ASYNC_OBSERVERS%22%3Afalse%2C%22_JQUERY_INTEGRATION%22%3Afalse%2C%22_TEMPLATE_ONLY_GLIMMER_COMPONENTS%22%3Atrue%7D%2C%22APP%22%3A%7B%22rumConfig%22%3A%7B%22pageKeyPrefix%22%3A%22d_%22%2C%22beacon-service%22%3A%22tracking%22%2C%22event-name%22%3A%22RealUserMonitoringEvent%22%2C%22enable-cdn-tracking%22%3Atrue%2C%22enable-pop-tracking%22%3Atrue%2C%22user-timing-mark-enabled%22%3Atrue%7D%7D%2C%22ember-media-player%22%3A%7B%22lazyLoad%22%3Atrue%2C%22plugins%22%3A%7B%7D%7D%2C%22eyeglass%22%3A%7B%22cssDir%22%3A%22assets%22%2C%22relativeAssets%22%3Afalse%7D%2C%22changeTracker%22%3A%7B%22auto%22%3Afalse%2C%22trackHasMany%22%3Afalse%7D%2C%22tracking%22%3A%7B%22appId%22%3A%22com.linkedin.sales2.d_web%22%2C%22topicPrefix%22%3A%22%22%2C%22pageKeyPrefix%22%3A%22d_%22%2C%22pveTrackingInfo%22%3A%7B%22osName%22%3A%22desktop%22%7D%2C%22trackingEndpoint%22%3A%22https%3A%2F%2Fwww.linkedin.com%2F7O4iJ3weJ-Ofi3N7QkD%22%2C%22comScore%22%3A%7B%22enabled%22%3Afalse%7D%2C%22validation%22%3A%7B%22throwOnError%22%3Afalse%7D%7D%2C%22lix%22%3A%7B%22lixKeys%22%3A%5B%22privacy.cpra.shared%22%2C%22lss.hue-infra-migration%22%2C%22lss.hue-infra-theme%22%2C%22lss.hue-infra-page-all-routes%22%2C%22lss-industry-v2-FE%22%2C%22lss-search-pci-field-versioning-FE%22%2C%22lss.global-header.referrals-icon%22%2C%22lss.search.last_viewed_column%22%2C%22lss-search.occupation-filter%22%2C%22enterprise.multiadmin.lss.accountcenter.debranding%22%2C%22lss-desktop-internal-feedback%22%2C%22lss-alert-tab-to-pill%22%2C%22lss.profile.useNewRecommendationsApi%22%2C%22lss.ssi.allow-guest-users%22%2C%22lss_custom_list.list_entity_edit_modal%22%2C%22lss.ent-exp.list-insights.bob-entry-point%22%2C%22lss-search-account-search-account-list-filter-member%22%2C%22lss.save-cta.redesign%22%2C%22lss.pages.save-cta.consistent-experience%22%2C%22lss.pages.save-cta.encourage-saves%22%2C%22lss.pages.save-cta.encourage-saves.testing%22%2C%22lss.pages.save-cta.lists-unsave-improvements%22%2C%22lss-lead-page-redesign%22%2C%22lss-lead-page-redesign-exclude-bots%22%2C%22lss-lead-page-redesign-exclude-bots-newbies%22%2C%22lss.growth.onboarding.contextual-tooltips-v2-all-tiers%22%2C%22lss.alerts.request.count%22%2C%22lss.pages.new-lead-page.relationship-empty-states-layout%22%2C%22lss.pages.lead-page.recent-activities-section%22%2C%22lss.pages.show-legacy-account-list-details-page%22%2C%22lss.buyer-interest.dashboard.top-accounts-v2-dev%22%2C%22lss.buyer-interest.search-highlight-hoverable%22%2C%22lss.notifications.buyer-activities-aggregation%22%2C%22lss.buyer-intent.enable-connection-to-your-colleagues%22%2C%22lss.accounts-dashboard.caching%22%2C%22lss.accounts.accounts-dashboard-dev%22%2C%22lss.account-hub.default-start-page%22%2C%22lss.buyer-interest.show-legacy-buyer-all-saved-accounts%22%2C%22lss.reflow.lower-min-width-all-routes%22%2C%22lss.admin-settings.reflow%22%2C%22lss.growth.reduced-onboarding-flow%22%2C%22lss.growth.retry-onboarding%22%2C%22lss-search.account-lti-headcount%22%2C%22lss.sales_api.lead_list.relationship_teamlink_connection_member%22%2C%22lss.search.saved-label-on-entity-lockup%22%2C%22spyglass.experimental.tsv-export%22%2C%22lss-apply-query-annotations-for-suggested-filters%22%2C%22lss.home.relationship-explorer-entry%22%2C%22lss-local-sales-web-redirect%22%2C%22lss.alerts.filter-by-list%22%2C%22lss.notifications.notifications-panel%22%2C%22lss.notifications.panel-from-flagship%22%2C%22ats.ramp.sales-web%22%2C%22ats.ramp.sales-web.admin%22%2C%22ats.ramp.sales-web.admi ...
# <!-- EMBER_CLI_FASTBOOT_TITLE --><!-- EMBER_CLI_FASTBOOT_HEAD -->
# <link href="https://static.licdn.com/aero-v1/sc/h/8cid09dn4abwh9sygrmp48elf" id="favicon-ico" rel="alternate icon" sizes="any"/>
# <link href="https://static.licdn.com/aero-v1/sc/h/3w39iyg1mpqyl92x6w8hks3l" rel="apple-touch-icon"/>
# <link href="https://static.licdn.com/aero-v1/sc/h
ue-web-icons/assets/images/app-icons/learning-small.svg":"https://static.licdn.com/aero-v1/sc/h/1p6vd4mwtnrnn9jxs9vxvaxhi","hue-web-icons/assets/images/app-icons/profinder-medium.svg":"https://static.licdn.com/aero-v1/sc/h/18yzx7nzpkcb0q8mvapcxfxzx","hue-web-icons/assets/images/app-icons/profinder-small.svg":"https://static.licdn.com/aero-v1/sc/h/4w3u4xpkw09kkydhm72cqyaq","hue-web-icons/assets/images/app-icons/pulse-medium.svg":"https://static.licdn.com/aero-v1/sc/h/5y72uzbxxko0q2sit9l88rio2","hue-web-icons/assets/images/app-icons/recruiter-medium.svg":"https://static.licdn.com/aero-v1/sc/h/67zjmvp6xejhnojw38w7zl9wk","hue-web-icons/assets/images/app-icons/recruiter-small.svg":"https://static.licdn.com/aero-v1/sc/h/qrzckv989c76ok55c0e5rmii","hue-web-icons/assets/images/app-icons/referrals-medium.svg":"https://static.licdn.com/aero-v1/sc/h/49on2g4si0ydausjeroe3sfds","hue-web-icons/assets/images/app-icons/salary-medium.svg":"https://static.licdn.com/aero-v1/sc/h/9mv49vv11libsa4d3329mdbjb","hue-web-icons/assets/images/app-icons/salary-small.svg":"https://static.licdn.com/aero-v1/sc/h/2ht0ba9fqpena58q1b7wx1ycu","hue-web-icons/assets/images/app-icons/sales-insights-medium.svg":"https://static.licdn.com/aero-v1/sc/h/8xcorgaqlpxuaa1fnl55rghel","hue-web-icons/assets/images/app-icons/sales-insights-small.svg":"https://static.licdn.com/aero-v1/sc/h/58dqdqr2iokd4vghc1fqpykbz","hue-web-icons/ ...
# <meta content="en_US" name="i18nDefaultLocale"/>
# <meta content="en_US" name="i18nLocale"/>
# <meta content="ng" name="requestIpCountryCode"/>
# <meta content="urn:li:page:bpr;f513c20b-ad57-4db8-8f49-8f10e17d50d2" name="bprPageInstance"/>
# <meta content='{"applicationUrn": "urn:li:application:(lighthouse-web,lighthouse-web)", "version": "1.0.8447", "trackingId": [-121, -34, 13, 25, -5, 5, 65, 15, -82, -84, 58, -97, 120, -90, 93, 103]}' name="applicationInstance"/>
# <meta content="a94193fe-89e6-450a-9267-c8b4b660f2e7" name="clientPageInstanceId"/>
# <meta content="lighthouse-web" name="service"/>
# <meta content="i001" name="serviceInstance"/>
# <meta content="1.0.8447" name="serviceVersion"/>
# <meta content="AAYOxqVyIZRYnZha1m9nTw==" name="treeID"/>
# <meta content="none" name="liamOrLisa"/>
# <meta content='{"lixV3Mode":false,"lix":{"lss.pages.save-cta.encourage-saves":{"treatment":"enabled","trackingInfo":null,"testKey":"lss.pages.save-cta.encourage-saves","primaryEvaluationUrn":null,"recursiveResults":null},"lss-alert-tab-to-pill":{"treatment":"enabled","trackingInfo":null,"testKey":"lss-alert-tab-to-pill","primaryEvaluationUrn":null,"recursiveResults":null},"lss.growth.onboarding.contextual-tooltips-v2-all-tiers":{"treatment":"enabled","trackingInfo":null,"testKey":"lss.growth.onboarding.contextual-tooltips-v2-all-tiers","primaryEvaluationUrn":null,"recursiveResults":null},"lss.home.relationship-explorer-entry":{"treatment":"control","trackingInfo":null,"testKey":"lss.home.relationship-explorer-entry","primaryEvaluationUrn":null,"recursiveResults":null},"lss.pages.lead-page.recent-activities-section":{"treatment":"enabled","trackingInfo":null,"testKey":"lss.pages.lead-page.recent-activities-section","primaryEvaluationUrn":null,"recursiveResults":null},"lss.pages.save-cta.consistent-experience":{"treatment":"enabled","trackingInfo":null,"testKey":"lss.pages.save-cta.consistent-experience","primaryEvaluationUrn":null,"recursiveResults":null},"lss.profile.useNewRecommendationsApi":{"treatment":"control","trackingInfo":null,"testKey":"lss.profile.useNewRecommendationsApi","primaryEvaluationUrn":null,"recursiveResults":null},"lss.accounts.accounts-dashboard-dev":{"treatment":"control","trackingInfo":null,"testKey":"lss.accounts.accounts-dashboard-dev","primaryEvaluationUrn":null,"recursiveResults":null},"lss.notifications.panel-from-flagship":{"treatment":"control","trackingInfo":null,"testKey":"lss.notifications.panel-from-flagship","primaryEvaluationUrn":null,"recursiveResults":null},"lss.ssi.allow-guest-users":{"treatment":"enabled","trackingInfo":null,"testKey":"lss.ssi.allow-guest-users","primaryEvaluationUrn":null,"recursiveResults":null},"lss.growth.retry-onboarding":{"treatment":"enabled","trackingInfo":null,"testKey":"lss.growth.retry-onboarding","primaryEvaluationUrn":null,"recursiveResults":null},"lss-search.account-lti-headcount":{"treatment":"enabled","trackingInfo":null,"testKey":"lss-search.account-lti-headcount","primaryEvaluationUrn":null,"recursiveResults":null},"lss.hue-infra-migration":{"treatment":"control","trackingInfo":null,"testKey":"lss.hue-infra-migration","primaryEvaluationUrn":null,"recursiveResults":null},"lss-desktop-internal-feedback":{"treatment":"control","trackingInfo":null,"testKey":"lss-desktop-internal-feedback","primaryEvaluationUrn":null,"recursiveResults":null},"lss.notifications.buyer-activities-aggregation":{"treatment":"enabled","trackingInfo":null,"testKey":"lss.notifications.buyer-activities-aggregation","primaryEvaluationUrn":null,"recursiveResults":null},"ats.ramp.sales-web.admin":{"treatment":"control","trackingInfo":null,"testKey":"ats.ramp.sales-web.admin","primaryEvaluationUrn":null,"recursiveResults":null},"lss.notifications.notifications-panel":{"treatment":"control","trackingInfo":null,"testKey":"lss.notifications.notifications-panel","primaryEvaluationUrn":null,"recursiveResults":null},"lss.growth-trust.account-under-review-redirect":{"treatment":"enabled","trackingInfo":null,"testKey":"lss.growth-trust.account-under-review-redirect","primaryEvaluationUrn":null,"recursiveResults":null},"lss-apply-query-annotations-for-suggested-filters":{"treatment":"control","trackingInfo":null,"testKey":"lss-apply-query-annotations-for-suggested-filters","primaryEvaluationUrn":null,"recursiveResults":null},"lss.alerts.filter-by-list":{"treatment":"enabled","trackingInfo":null,"testKey":"lss.alerts.filter-by-list","primaryEvaluationUrn":null,"recursiveResults":null},"ats.ramp.sales-web.admin-settings":{"treatment":"enabled","trackingInfo":null,"testKey":"ats.ramp.sales-web.admin-settings","primaryEvaluationUrn":null,"recursiveResults":null},"lss.growth.reduced-onboarding-flow":{"treatment":"control","trackingInfo":null,"testKey":"lss.growth.reduced-onboarding-flow","primaryEval ...
# <meta content="true" name="isBrowserSupported"/>
# <meta content="true" name="isGuest"/>
# <meta data-mode="VANILLA" name="renderingMode"/>
# <!--%SSR_HEAD*[]%-->
# <meta content="true" name="isQueryTunnelRequestSupported">
# <link href="https://static.licdn.com/aero-v1/sc/h/5d7nbdca6a6j80p55pxbkjsg2" rel="stylesheet"/>
# <link href="https://static.licdn.com/aero-v1/sc/h/1fkodsy33m2gzo2n5ts22cjp8" rel="stylesheet"/>
# <meta content="https://static.licdn.com/aero-v1/sc/h/4upgxfhayj4r4ly3uoyyw46cp" id="artdeco-icons/static/images/icons.svg" name="asset-url"/>
# </meta></head>
# <body>
# <!-- EMBER_CLI_FASTBOOT_BODY -->
# <div id="hue-web-menu-outlet"></div>
# <div id="hue-web-modal-outlet"></div>
# <div id="hue-web-tooltip-outlet"></div>
# <div id="hue-web-typeahead-outlet"></div>
# <script crossorigin="" data-fastboot-src="assets/polyfill-shared.js" src="https://static.licdn.com/aero-v1/sc/h/b73x9uk4nyp02zap5yi7lxr8x"></script>
# <script crossorigin="" data-fastboot-src="assets/polyfill-legacy.js" nomodule="" src="https://static.licdn.com/aero-v1/sc/h/2sk7rsvzeg1dvnrtc2bxbciw1"></script>
# <script crossorigin="" data-fastboot-src="assets/polyfill-evergreen.js" src="https://static.licdn.com/aero-v1/sc/h/67nsh6jy719jgjvynwwvx3pjn"></script>
# <div class="initial-loading-state">
# <div class="initial-load-animation">
# <div class="salesnav-image"></div>
# <div class="loading-bar">
# <div class="blue-bar"></div>
# </div>
# </div>
# </div>
# <script crossorigin="" data-fastboot-src="assets/vendor.js" src="https://static.licdn.com/aero-v1/sc/h/5hh3tk4ht4pw09y5mhda58aha"></script>
# <script crossorigin="" data-fastboot-src="/assets/chunk.846.9427cf2e17b677e5a01a.js" src="https://static.licdn.com/aero-v1/sc/h/66b7udy9nf1jqe9efht6dxlw7"></script>
# <script crossorigin="" data-fastboot-src="/assets/chunk.143.c0bfbd156dda28471e92.js" src="https://static.licdn.com/aero-v1/sc/h/6ktmohkca4re03tj4thtg17fo"></script>
# <script crossorigin="" data-fastboot-src="assets/i18n/support_en_US.js" src="https://static.licdn.com/aero-v1/sc/h/gqanmm5yahnwmj8vgpzlmw1u"></script>
# <script crossorigin="" data-fastboot-src="assets/lighthouse-web.js" src="https://static.licdn.com/aero-v1/sc/h/6u6dujxmh0xixgnnzvjcbeauj"></script>
# <div id="artdeco-modal-outlet"></div>
# <!--%SSR_BODY*[]%-->
# <div id="ember-panel-outlet"></div>
# </body></html>

# %%
nams = soup.find('h1', class_='artdeco-entity-lockup--size-4 .artdeco-entity-lockup__title')

# %%
print(nams)
# Out:
# None

# %%
print(soup.find('div'))
# Out:
# <div id="hue-web-menu-outlet"></div>

# %%
api=9698c747bd888fbd02884d64a4004554

# %%
import requests

payload = { 'api_key': '9698c747bd888fbd02884d64a4004554', 'url': 'https://drive.google.com/file/d/1Eqbt2ImGI3WBKgvjMTGc7HbrIW5PRozC/view?usp=sharing', 'country_code': 'us' } 
r = requests.get('https://api.scraperapi.com/', params=payload)
print(r.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
r
# Out:
# <Response [200]>
